# %% [markdown]
# # Scraping Data

# %%
# %pip install google-play-scraper

# %%
from google_play_scraper import app, reviews
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
app_id = 'com.zte.iptvclient.android.idmnc'

# Mengambil ulasan
reviews_data, _ = reviews(
    app_id,
    lang='id',
    country='id',
    count=50000
)

# Konversi ke DataFrame
reviews_data = pd.DataFrame(reviews_data)
reviews_data
# Out:
#                                    reviewId         userName  \
# 0      a93920d8-e94b-44c1-a5b3-288e18bc8ee7  Pengguna Google
# 1      f51f2ae1-85ad-42de-834b-680b2aa513a4  Pengguna Google
# 2      1e4bd6d1-8a57-450a-86bd-96c39983484f  Pengguna Google
# 3      a106bd81-a19d-4908-8ad5-b814e09d2a5b  Pengguna Google
# 4      3eb38928-3afd-4e12-b26c-cc86f17317a3  Pengguna Google
# ...                                     ...              ...
# 49995  f196214b-b365-4e41-a6f1-d5bae842bb79  Pengguna Google
# 49996  d18eccb6-1ac3-4031-b255-e3ea2aa1aeb5  Pengguna Google
# 49997  85b0b7f8-813e-46b2-ae41-9ca3471690f9  Pengguna Google
# 49998  296cf91c-d505-4d42-b86f-faed179d1d0b  Pengguna Google
# 49999  fdafafd6-6d78-4762-8025-b9a041929021  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
# save to csv
reviews_data.to_csv('visionplus_reviews.csv', index=False)
